# %%
import pandas as pd

# import api keys
from api_keys import flight_api_key, OWM_key

# %% [markdown]
# ## Flights API

# %%
from datetime import datetime, timedelta

airport_icoa = "EDDB"
to_local_time = datetime.now().strftime('%Y-%m-%dT%H:00')
from_local_time = (datetime.now() + timedelta(hours=9)).strftime('%Y-%m-%dT%H:00')
url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{airport_icoa}/{to_local_time}/{from_local_time}"


import requests

querystring = {"withLeg":"true","withCancelled":"true","withCodeshared":"true","withCargo":"true","withPrivate":"false","withLocation":"false"}

headers = {
    'x-rapidapi-host': "aerodatabox.p.rapidapi.com",
    'x-rapidapi-key': flight_api_key
    }

response = requests.request("GET", url, headers=headers, params=querystring)

from IPython.display import JSON
response.json()
# Out:
# {'departures': [{'departure': {'scheduledTimeLocal': '2022-10-07 14:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 12:10Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'ENGM', 'iata': 'OSL', 'name': 'Oslo'},
#     'scheduledTimeLocal': '2022-10-07 15:50+02:00',
#     'actualTimeLocal': '2022-10-07 15:56+02:00',
#     'scheduledTimeUtc': '2022-10-07 13:50Z',
#     'actualTimeUtc': '2022-10-07 13:56Z',
#     'quality': ['Basic', 'Live']},
#    'number': 'DY 1105',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Norwegian Air Shuttle'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 14:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 12:10Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LTAI', 'iata': 'AYT', 'name': 'Antalya'},
#     'scheduledTimeLocal': '2022-10-07 18:30+03:00',
#     'scheduledTimeUtc': '2022-10-07 15:30Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'TK 7895',
#    'status': 'CanceledUncertain',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321'},
#    'airline': {'name': 'Turkish'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 14:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 12:10Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LSZH', 'iata': 'ZRH', 'name': 'Zurich'},
#     'scheduledTimeLocal': '2022-10-07 15:45+02:00',
#     'scheduledTimeUtc': '2022-10-07 13:45Z',
#     'quality': ['Basic']},
#    'number': 'U2 5867',
#    'status': 'CanceledUncertain',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 14:15+02:00',
#     'scheduledTimeUtc': '2022-10-07 12:15Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'BIKF', 'iata': 'KEF', 'name': 'Reykjavik'},
#     'scheduledTimeLocal': '2022-10-07 15:50+00:00',
#     'actualTimeLocal': '2022-10-07 15:50+00:00',
#     'scheduledTimeUtc': '2022-10-07 15:50Z',
#     'actualTimeUtc': '2022-10-07 15:50Z',
#     'quality': ['Basic', 'Live']},
#    'number': 'FI 529',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737'},
#    'airline': {'name': 'Icelandair'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 14:20+02:00',
#     'scheduledTimeUtc': '2022-10-07 12:20Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EHAM', 'iata': 'AMS', 'name': 'Amsterdam'},
#     'scheduledTimeLocal': '2022-10-07 15:45+02:00',
#     'actualTimeLocal': '2022-10-07 16:03+02:00',
#     'runwayTimeLocal': '2022-10-07 16:03+02:00',
#     'scheduledTimeUtc': '2022-10-07 13:45Z',
#     'actualTimeUtc': '2022-10-07 14:03Z',
#     'runwayTimeUtc': '2022-10-07 14:03Z',
#     'terminal': '2',
#     'baggageBelt': '12',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 1826',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 195-E2'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 14:20+02:00',
#     'scheduledTimeUtc': '2022-10-07 12:20Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LIML', 'iata': 'LIN', 'name': 'Milan'},
#     'scheduledTimeLocal': '2022-10-07 16:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:10Z',
#     'quality': ['Basic']},
#    'number': 'U2 5185',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 14:30+02:00',
#     'scheduledTimeUtc': '2022-10-07 12:30Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EPKK', 'iata': 'KRK', 'name': 'Kraków'},
#     'scheduledTimeLocal': '2022-10-07 15:45+02:00',
#     'scheduledTimeUtc': '2022-10-07 13:45Z',
#     'quality': ['Basic']},
#    'number': 'FR 2535',
#    'status': 'CanceledUncertain',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 14:35+02:00',
#     'scheduledTimeUtc': '2022-10-07 12:35Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EGSS', 'iata': 'STN', 'name': 'London'},
#     'scheduledTimeLocal': '2022-10-07 15:25+01:00',
#     'actualTimeLocal': '2022-10-07 15:25+01:00',
#     'scheduledTimeUtc': '2022-10-07 14:25Z',
#     'actualTimeUtc': '2022-10-07 14:25Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 8545',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 14:35+02:00',
#     'scheduledTimeUtc': '2022-10-07 12:35Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'ORER', 'iata': 'EBL', 'name': 'Arbil'},
#     'scheduledTimeLocal': '2022-10-07 19:35+03:00',
#     'scheduledTimeUtc': '2022-10-07 16:35Z',
#     'quality': ['Basic']},
#    'number': 'IA 264',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737'},
#    'airline': {'name': 'I A W'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 14:40+02:00',
#     'scheduledTimeUtc': '2022-10-07 12:40Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LGKO',
#      'iata': 'KGS',
#      'name': 'Kos Island'},
#     'scheduledTimeLocal': '2022-10-07 18:40+03:00',
#     'scheduledTimeUtc': '2022-10-07 15:40Z',
#     'quality': ['Basic']},
#    'number': 'EW 8670',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 14:40+02:00',
#     'scheduledTimeUtc': '2022-10-07 12:40Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LTBJ', 'iata': 'ADB', 'name': 'İzmir'},
#     'scheduledTimeLocal': '2022-10-07 18:35+03:00',
#     'actualTimeLocal': '2022-10-07 18:35+03:00',
#     'scheduledTimeUtc': '2022-10-07 15:35Z',
#     'actualTimeUtc': '2022-10-07 15:35Z',
#     'terminal': 'I',
#     'baggageBelt': '01',
#     'quality': ['Basic', 'Live']},
#    'number': 'XQ 947',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'SunExpress'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 14:45+02:00',
#     'scheduledTimeUtc': '2022-10-07 12:45Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTimeLocal': '2022-10-07 15:55+02:00',
#     'actualTimeLocal': '2022-10-07 16:25+02:00',
#     'scheduledTimeUtc': '2022-10-07 13:55Z',
#     'actualTimeUtc': '2022-10-07 14:25Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 187',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIRT', 'modeS': '3C6654', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 14:50+02:00',
#     'scheduledTimeUtc': '2022-10-07 12:50Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LPPT', 'iata': 'LIS', 'name': 'Lisbon'},
#     'scheduledTimeLocal': '2022-10-07 17:30+01:00',
#     'actualTimeLocal': '2022-10-07 17:30+01:00',
#     'scheduledTimeUtc': '2022-10-07 16:30Z',
#     'actualTimeUtc': '2022-10-07 16:30Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 1142',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 14:50+02:00',
#     'scheduledTimeUtc': '2022-10-07 12:50Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EYVI', 'iata': 'VNO', 'name': 'Vilnius'},
#     'scheduledTimeLocal': '2022-10-07 17:25+03:00',
#     'scheduledTimeUtc': '2022-10-07 14:25Z',
#     'quality': ['Basic']},
#    'number': 'FR 1570',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 14:55+02:00',
#     'scheduledTimeUtc': '2022-10-07 12:55Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTimeLocal': '2022-10-07 16:05+02:00',
#     'actualTimeLocal': '2022-10-07 16:05+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:05Z',
#     'actualTimeUtc': '2022-10-07 14:05Z',
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1957',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Bombardier CRJ900'},
#    'airline': {'name': 'Lufthansa'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 14:55+02:00',
#     'scheduledTimeUtc': '2022-10-07 12:55Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LSZH', 'iata': 'ZRH', 'name': 'Zurich'},
#     'scheduledTimeLocal': '2022-10-07 16:20+02:00',
#     'actualTimeLocal': '2022-10-07 16:20+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:20Z',
#     'actualTimeUtc': '2022-10-07 14:20Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 967',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-IOM', 'modeS': '4B1698', 'model': 'Airbus A321'},
#    'airline': {'name': 'SWISS'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 14:55+02:00',
#     'scheduledTimeUtc': '2022-10-07 12:55Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LTFM', 'iata': 'IST', 'name': 'Istanbul'},
#     'scheduledTimeLocal': '2022-10-07 18:50+03:00',
#     'scheduledTimeUtc': '2022-10-07 15:50Z',
#     'quality': ['Basic']},
#    'number': 'TK 1726',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321'},
#    'airline': {'name': 'Turkish'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 15:05+02:00',
#     'scheduledTimeUtc': '2022-10-07 13:05Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LOWW', 'iata': 'VIE', 'name': 'Vienna'},
#     'scheduledTimeLocal': '2022-10-07 16:20+02:00',
#     'actualTimeLocal': '2022-10-07 16:20+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:20Z',
#     'actualTimeUtc': '2022-10-07 14:20Z',
#     'terminal': '3',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 230',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Austrian'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 15:05+02:00',
#     'scheduledTimeUtc': '2022-10-07 13:05Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen'},
#     'scheduledTimeLocal': '2022-10-07 16:00+02:00',
#     'actualTimeLocal': '2022-10-07 16:00+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:00Z',
#     'actualTimeUtc': '2022-10-07 14:00Z',
#     'terminal': '3',
#     'gate': 'D2',
#     'quality': ['Basic', 'Live']},
#    'number': 'SK 1674',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'SAS'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 15:05+02:00',
#     'scheduledTimeUtc': '2022-10-07 13:05Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LFBD',
#      'iata': 'BOD',
#      'name': 'Bordeaux/Mérignac'},
#     'scheduledTimeLocal': '2022-10-07 17:30+02:00',
#     'scheduledTimeUtc': '2022-10-07 15:30Z',
#     'terminal': 'L',
#     'quality': ['Basic']},
#    'number': 'U2 4366',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 15:15+02:00',
#     'scheduledTimeUtc': '2022-10-07 13:15Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LEVC', 'iata': 'VLC', 'name': 'Valencia'},
#     'scheduledTimeLocal': '2022-10-07 18:20+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:20Z',
#     'quality': ['Basic']},
#    'number': 'U2 4517',
#    'status': 'CanceledUncertain',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 15:20+02:00',
#     'scheduledTimeUtc': '2022-10-07 13:20Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'scheduledTimeLocal': '2022-10-07 17:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 15:10Z',
#     'terminal': '2F',
#     'quality': ['Basic']},
#    'number': 'AF 1235',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Air France'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 15:30+02:00',
#     'scheduledTimeUtc': '2022-10-07 13:30Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'name': 'Barcelona'}, 'quality': []},
#    'number': 'U2 4529',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 15:40+02:00',
#     'scheduledTimeUtc': '2022-10-07 13:40Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LGAV', 'iata': 'ATH', 'name': 'Athens'},
#     'scheduledTimeLocal': '2022-10-07 19:35+03:00',
#     'scheduledTimeUtc': '2022-10-07 16:35Z',
#     'quality': ['Basic']},
#    'number': 'U2 5937',
#    'status': 'CanceledUncertain',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 15:45+02:00',
#     'scheduledTimeUtc': '2022-10-07 13:45Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'HECA', 'iata': 'CAI', 'name': 'Cairo'},
#     'scheduledTimeLocal': '2022-10-07 19:50+02:00',
#     'scheduledTimeUtc': '2022-10-07 17:50Z',
#     'terminal': '2',
#     'quality': ['Basic']},
#    'number': 'MS 732',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'EgyptAir'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 15:55+02:00',
#     'scheduledTimeUtc': '2022-10-07 13:55Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDK', 'iata': 'CGN', 'name': 'Cologne'},
#     'scheduledTimeLocal': '2022-10-07 17:00+02:00',
#     'scheduledTimeUtc': '2022-10-07 15:00Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'EW 8070',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 16:05+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:05Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LGTS',
#      'iata': 'SKG',
#      'name': 'Thessaloniki'},
#     'scheduledTimeLocal': '2022-10-07 19:25+03:00',
#     'scheduledTimeUtc': '2022-10-07 16:25Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'number': 'A3 513',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Aegean'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 16:05+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:05Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EHAM', 'iata': 'AMS', 'name': 'Amsterdam'},
#     'scheduledTimeLocal': '2022-10-07 17:35+02:00',
#     'scheduledTimeUtc': '2022-10-07 15:35Z',
#     'quality': ['Basic']},
#    'number': 'U2 4565',
#    'status': 'CanceledUncertain',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 16:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:10Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'OTHH', 'iata': 'DOH', 'name': 'Doha'},
#     'scheduledTimeLocal': '2022-10-07 22:40+03:00',
#     'scheduledTimeUtc': '2022-10-07 19:40Z',
#     'quality': ['Basic']},
#    'number': 'QR 82',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 787-9'},
#    'airline': {'name': 'Qatar Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 16:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:10Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LEPA',
#      'iata': 'PMI',
#      'name': 'Palma De Mallorca'},
#     'scheduledTimeLocal': '2022-10-07 18:55+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:55Z',
#     'quality': ['Basic']},
#    'number': 'U2 5815',
#    'status': 'CanceledUncertain',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 16:20+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:20Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EGNX',
#      'iata': 'EMA',
#      'name': 'Nottingham'},
#     'scheduledTimeLocal': '2022-10-07 17:20+01:00',
#     'actualTimeLocal': '2022-10-07 17:20+01:00',
#     'scheduledTimeUtc': '2022-10-07 16:20Z',
#     'actualTimeUtc': '2022-10-07 16:20Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 1639',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 16:20+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:20Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LUKK', 'iata': 'KIV', 'name': 'Chişinău'},
#     'scheduledTimeLocal': '2022-10-07 19:30+03:00',
#     'scheduledTimeUtc': '2022-10-07 16:30Z',
#     'quality': ['Basic']},
#    'number': 'W6 6904',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Wizz Air'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 16:25+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:25Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LEPA',
#      'iata': 'PMI',
#      'name': 'Palma De Mallorca'},
#     'scheduledTimeLocal': '2022-10-07 19:10+02:00',
#     'actualTimeLocal': '2022-10-07 19:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 17:10Z',
#     'actualTimeUtc': '2022-10-07 17:10Z',
#     'terminal': 'N',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 280',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 16:30+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:30Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LTFJ', 'iata': 'SAW', 'name': 'Istanbul'},
#     'scheduledTimeLocal': '2022-10-07 20:25+03:00',
#     'scheduledTimeUtc': '2022-10-07 17:25Z',
#     'quality': ['Basic']},
#    'number': 'PC 978',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321'},
#    'airline': {'name': 'Pegasus'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 16:35+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:35Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EGGD', 'iata': 'BRS', 'name': 'Bristol'},
#     'scheduledTimeLocal': '2022-10-07 17:40+01:00',
#     'scheduledTimeUtc': '2022-10-07 16:40Z',
#     'quality': ['Basic']},
#    'number': 'U2 6238',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 16:45+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:45Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EGLL', 'iata': 'LHR', 'name': 'London'},
#     'scheduledTimeLocal': '2022-10-07 17:40+01:00',
#     'actualTimeLocal': '2022-10-07 17:40+01:00',
#     'scheduledTimeUtc': '2022-10-07 16:40Z',
#     'actualTimeUtc': '2022-10-07 16:40Z',
#     'terminal': '5',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 985',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'British Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 16:45+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:45Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTimeLocal': '2022-10-07 17:55+02:00',
#     'actualTimeLocal': '2022-10-07 17:55+02:00',
#     'scheduledTimeUtc': '2022-10-07 15:55Z',
#     'actualTimeUtc': '2022-10-07 15:55Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 195',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIUK', 'modeS': '3C66AB', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 16:50+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:50Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EGLC', 'iata': 'LCY', 'name': 'London'},
#     'scheduledTimeLocal': '2022-10-07 16:40+01:00',
#     'actualTimeLocal': '2022-10-07 16:23+01:00',
#     'scheduledTimeUtc': '2022-10-07 15:40Z',
#     'actualTimeUtc': '2022-10-07 15:23Z',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 8494',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'British Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 16:50+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:50Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTimeLocal': '2022-10-07 18:00+02:00',
#     'actualTimeLocal': '2022-10-07 18:00+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:00Z',
#     'actualTimeUtc': '2022-10-07 16:00Z',
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1945',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 16:50+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:50Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LIML', 'iata': 'LIN', 'name': 'Milan'},
#     'scheduledTimeLocal': '2022-10-07 18:40+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:40Z',
#     'quality': ['Basic']},
#    'number': 'U2 4677',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 16:55+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:55Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDS', 'iata': 'STR', 'name': 'Stuttgart'},
#     'scheduledTimeLocal': '2022-10-07 18:10+02:00',
#     'actualTimeLocal': '2022-10-07 18:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:10Z',
#     'actualTimeUtc': '2022-10-07 16:10Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 2009',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 17:00+02:00',
#     'scheduledTimeUtc': '2022-10-07 15:00Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDK', 'iata': 'CGN', 'name': 'Cologne'},
#     'scheduledTimeLocal': '2022-10-07 18:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:10Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'EW 53',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 17:00+02:00',
#     'scheduledTimeUtc': '2022-10-07 15:00Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LOWW', 'iata': 'VIE', 'name': 'Vienna'},
#     'scheduledTimeLocal': '2022-10-07 18:15+02:00',
#     'actualTimeLocal': '2022-10-07 18:15+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:15Z',
#     'actualTimeUtc': '2022-10-07 16:15Z',
#     'terminal': '3',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 232',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Austrian'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 17:05+02:00',
#     'scheduledTimeUtc': '2022-10-07 15:05Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LGTS',
#      'iata': 'SKG',
#      'name': 'Thessaloniki'},
#     'scheduledTimeLocal': '2022-10-07 20:30+03:00',
#     'scheduledTimeUtc': '2022-10-07 17:30Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'number': 'FR 1146',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 17:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 15:10Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf'},
#     'scheduledTimeLocal': '2022-10-07 18:25+02:00',
#     'actualTimeLocal': '2022-10-07 18:25+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:25Z',
#     'actualTimeUtc': '2022-10-07 16:25Z',
#     'terminal': 'A',
#     'gate': 'A39',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 9041',
#    'callSign': 'GWI10G',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ABGP', 'modeS': '3C48F0', 'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 17:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 15:10Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LIRN', 'iata': 'NAP', 'name': 'Nápoli'},
#     'scheduledTimeLocal': '2022-10-07 19:30+02:00',
#     'scheduledTimeUtc': '2022-10-07 17:30Z',
#     'quality': ['Basic']},
#    'number': 'U2 4575',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 17:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 15:10Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LFSB',
#      'iata': 'BSL',
#      'name': 'Bâle/Mulhouse'},
#     'scheduledTimeLocal': '2022-10-07 18:40+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:40Z',
#     'quality': ['Basic']},
#    'number': 'U2 4637',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 17:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 15:10Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LTBJ', 'iata': 'ADB', 'name': 'İzmir'},
#     'scheduledTimeLocal': '2022-10-07 20:55+03:00',
#     'actualTimeLocal': '2022-10-07 20:55+03:00',
#     'scheduledTimeUtc': '2022-10-07 17:55Z',
#     'actualTimeUtc': '2022-10-07 17:55Z',
#     'terminal': '0',
#     'baggageBelt': '05',
#     'quality': ['Basic', 'Live']},
#    'number': 'XC 3076',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Corendon Air'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 17:15+02:00',
#     'scheduledTimeUtc': '2022-10-07 15:15Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LPPT', 'iata': 'LIS', 'name': 'Lisbon'},
#     'scheduledTimeLocal': '2022-10-07 19:50+01:00',
#     'actualTimeLocal': '2022-10-07 19:50+01:00',
#     'scheduledTimeUtc': '2022-10-07 18:50Z',
#     'actualTimeUtc': '2022-10-07 18:50Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'TP 535',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'TAP Air Portugal'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 17:25+02:00',
#     'scheduledTimeUtc': '2022-10-07 15:25Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen'},
#     'scheduledTimeLocal': '2022-10-07 18:25+02:00',
#     'actualTimeLocal': '2022-10-07 18:25+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:25Z',
#     'actualTimeUtc': '2022-10-07 16:25Z',
#     'terminal': '3',
#     'quality': ['Basic', 'Live']},
#    'number': 'D8 3303',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737'},
#    'airline': {'name': 'Norwegian Air International'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 17:25+02:00',
#     'scheduledTimeUtc': '2022-10-07 15:25Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LTAI', 'iata': 'AYT', 'name': 'Antalya'},
#     'scheduledTimeLocal': '2022-10-07 21:45+03:00',
#     'scheduledTimeUtc': '2022-10-07 18:45Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'XQ 661',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'SunExpress'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 17:30+02:00',
#     'scheduledTimeUtc': '2022-10-07 15:30Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EHAM', 'iata': 'AMS', 'name': 'Amsterdam'},
#     'scheduledTimeLocal': '2022-10-07 18:50+02:00',
#     'actualTimeLocal': '2022-10-07 18:42+02:00',
#     'runwayTimeLocal': '2022-10-07 18:42+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:50Z',
#     'actualTimeUtc': '2022-10-07 16:42Z',
#     'runwayTimeUtc': '2022-10-07 16:42Z',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 1830',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 175'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 17:35+02:00',
#     'scheduledTimeUtc': '2022-10-07 15:35Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'ESSA', 'iata': 'ARN', 'name': 'Stockholm'},
#     'scheduledTimeLocal': '2022-10-07 19:10+02:00',
#     'actualTimeLocal': '2022-10-07 19:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 17:10Z',
#     'actualTimeUtc': '2022-10-07 17:10Z',
#     'terminal': '5',
#     'baggageBelt': '3',
#     'quality': ['Basic', 'Live']},
#    'number': 'D8 4506',
#    'callSign': 'NSZ4506',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'reg': 'LY-FJI', 'modeS': '503E36', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Norwegian Air International'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 16:50+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:50Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'ZYTL', 'iata': 'DLC', 'name': 'Dalian'},
#     'scheduledTimeLocal': '2022-10-08 08:25+08:00',
#     'scheduledTimeUtc': '2022-10-08 00:25Z',
#     'quality': ['Basic']},
#    'number': 'HU 490',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A330-300'},
#    'airline': {'name': 'Hainan'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 17:45+02:00',
#     'scheduledTimeUtc': '2022-10-07 15:45Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTimeLocal': '2022-10-07 18:55+02:00',
#     'actualTimeLocal': '2022-10-07 18:55+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:55Z',
#     'actualTimeUtc': '2022-10-07 16:55Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 197',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIZX', 'modeS': '3C6758', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 17:50+02:00',
#     'scheduledTimeUtc': '2022-10-07 15:50Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LIRF', 'iata': 'FCO', 'name': 'Rome'},
#     'scheduledTimeLocal': '2022-10-07 19:50+02:00',
#     'actualTimeLocal': '2022-10-07 19:50+02:00',
#     'scheduledTimeUtc': '2022-10-07 17:50Z',
#     'actualTimeUtc': '2022-10-07 17:50Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 140',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 17:50+02:00',
#     'scheduledTimeUtc': '2022-10-07 15:50Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTimeLocal': '2022-10-07 19:00+02:00',
#     'actualTimeLocal': '2022-10-07 19:00+02:00',
#     'scheduledTimeUtc': '2022-10-07 17:00Z',
#     'actualTimeUtc': '2022-10-07 17:00Z',
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1947',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 17:50+02:00',
#     'scheduledTimeUtc': '2022-10-07 15:50Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LSZH', 'iata': 'ZRH', 'name': 'Zurich'},
#     'scheduledTimeLocal': '2022-10-07 19:25+02:00',
#     'scheduledTimeUtc': '2022-10-07 17:25Z',
#     'quality': ['Basic']},
#    'number': 'U2 5873',
#    'status': 'CanceledUncertain',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 16:30+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:30Z',
#     'terminal': '2',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LFMT',
#      'iata': 'MPL',
#      'name': 'Montpellier/Méditerranée'},
#     'scheduledTimeLocal': '2022-10-07 18:40+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:40Z',
#     'quality': ['Basic']},
#    'number': 'TO 3415',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Transavia France'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 18:00+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:00Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'scheduledTimeLocal': '2022-10-07 19:50+02:00',
#     'scheduledTimeUtc': '2022-10-07 17:50Z',
#     'terminal': '2F',
#     'quality': ['Basic']},
#    'number': 'AF 1835',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Air France'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 18:00+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:00Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LTAI', 'iata': 'AYT', 'name': 'Antalya'},
#     'scheduledTimeLocal': '2022-10-07 22:10+03:00',
#     'scheduledTimeUtc': '2022-10-07 19:10Z',
#     'terminal': '2',
#     'quality': ['Basic']},
#    'number': 'FH 282',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Freebird'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 18:05+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:05Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EGCC',
#      'iata': 'MAN',
#      'name': 'Manchester'},
#     'scheduledTimeLocal': '2022-10-07 19:10+01:00',
#     'actualTimeLocal': '2022-10-07 19:10+01:00',
#     'scheduledTimeUtc': '2022-10-07 18:10Z',
#     'actualTimeUtc': '2022-10-07 18:10Z',
#     'terminal': '3',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 1144',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 16:30+02:00',
#     'scheduledTimeUtc': '2022-10-07 14:30Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LBSF', 'iata': 'SOF', 'name': 'Sofia'},
#     'scheduledTimeLocal': '2022-10-07 19:30+03:00',
#     'scheduledTimeUtc': '2022-10-07 16:30Z',
#     'terminal': '2',
#     'quality': ['Basic']},
#    'number': 'FB 320',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Bulgaria Air'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 18:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:10Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EFHK', 'iata': 'HEL', 'name': 'Helsinki'},
#     'scheduledTimeLocal': '2022-10-07 21:00+03:00',
#     'actualTimeLocal': '2022-10-07 21:00+03:00',
#     'scheduledTimeUtc': '2022-10-07 18:00Z',
#     'actualTimeUtc': '2022-10-07 18:00Z',
#     'terminal': '2',
#     'baggageBelt': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'AY 1438',
#    'status': 'Canceled',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Finnair'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 18:20+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:20Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDS', 'iata': 'STR', 'name': 'Stuttgart'},
#     'scheduledTimeLocal': '2022-10-07 19:35+02:00',
#     'actualTimeLocal': '2022-10-07 19:35+02:00',
#     'scheduledTimeUtc': '2022-10-07 17:35Z',
#     'actualTimeUtc': '2022-10-07 17:35Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 2019',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 18:20+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:20Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LIMC', 'iata': 'MXP', 'name': 'Milan'},
#     'scheduledTimeLocal': '2022-10-07 20:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 18:10Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'FR 8',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 18:20+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:20Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'ESSA', 'iata': 'ARN', 'name': 'Stockholm'},
#     'scheduledTimeLocal': '2022-10-07 20:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 18:10Z',
#     'terminal': '2',
#     'quality': ['Basic']},
#    'number': 'U2 5887',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 18:25+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:25Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EGSS', 'iata': 'STN', 'name': 'London'},
#     'scheduledTimeLocal': '2022-10-07 19:15+01:00',
#     'actualTimeLocal': '2022-10-07 19:15+01:00',
#     'scheduledTimeUtc': '2022-10-07 18:15Z',
#     'actualTimeUtc': '2022-10-07 18:15Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 146',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 18:30+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:30Z',
#     'terminal': '2',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LFPO', 'iata': 'ORY', 'name': 'Paris'},
#     'scheduledTimeLocal': '2022-10-07 20:20+02:00',
#     'scheduledTimeUtc': '2022-10-07 18:20Z',
#     'terminal': '3',
#     'quality': ['Basic']},
#    'number': 'TO 3409',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Transavia France'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 18:45+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:45Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTimeLocal': '2022-10-07 19:55+02:00',
#     'actualTimeLocal': '2022-10-07 19:55+02:00',
#     'scheduledTimeUtc': '2022-10-07 17:55Z',
#     'actualTimeUtc': '2022-10-07 17:55Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 199',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIRT', 'modeS': '3C6654', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 18:45+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:45Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LSZH', 'iata': 'ZRH', 'name': 'Zurich'},
#     'scheduledTimeLocal': '2022-10-07 20:10+02:00',
#     'actualTimeLocal': '2022-10-07 20:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 18:10Z',
#     'actualTimeUtc': '2022-10-07 18:10Z',
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 971',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-JCA',
#     'modeS': '4B17F8',
#     'model': 'Airbus A220-300'},
#    'airline': {'name': 'SWISS'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 18:45+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:45Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EBBR', 'iata': 'BRU', 'name': 'Brussels'},
#     'scheduledTimeLocal': '2022-10-07 20:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 18:10Z',
#     'quality': ['Basic']},
#    'number': 'SN 2588',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Brussels'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 18:45+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:45Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LTAC', 'iata': 'ESB', 'name': 'Ankara'},
#     'scheduledTimeLocal': '2022-10-07 22:50+03:00',
#     'actualTimeLocal': '2022-10-07 22:50+03:00',
#     'scheduledTimeUtc': '2022-10-07 19:50Z',
#     'actualTimeUtc': '2022-10-07 19:50Z',
#     'baggageBelt': '11',
#     'quality': ['Basic', 'Live']},
#    'number': 'TK 7733',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Turkish'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 18:45+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:45Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'name': 'Antalya'}, 'quality': []},
#    'number': 'XC 5372',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Corendon Air'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 18:50+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:50Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTimeLocal': '2022-10-07 20:00+02:00',
#     'actualTimeLocal': '2022-10-07 20:00+02:00',
#     'scheduledTimeUtc': '2022-10-07 18:00Z',
#     'actualTimeUtc': '2022-10-07 18:00Z',
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1949',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 18:50+02:00',
#     'scheduledTimeUtc': '2022-10-07 16:50Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LTAI', 'iata': 'AYT', 'name': 'Antalya'},
#     'scheduledTimeLocal': '2022-10-07 23:05+03:00',
#     'scheduledTimeUtc': '2022-10-07 20:05Z',
#     'terminal': 'D',
#     'quality': ['Basic']},
#    'number': 'PC 5008',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Pegasus'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 19:00+02:00',
#     'scheduledTimeUtc': '2022-10-07 17:00Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LIPH', 'iata': 'TSF', 'name': 'Treviso'},
#     'scheduledTimeLocal': '2022-10-07 20:35+02:00',
#     'scheduledTimeUtc': '2022-10-07 18:35Z',
#     'quality': ['Basic']},
#    'number': 'FR 2606',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 19:05+02:00',
#     'scheduledTimeUtc': '2022-10-07 17:05Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDK', 'iata': 'CGN', 'name': 'Cologne'},
#     'scheduledTimeLocal': '2022-10-07 20:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 18:10Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'EW 8054',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings'}},
#   {'departure': {'scheduledTimeLocal': '2022-10-07 19:05+02:00',
#     'scheduledTimeUtc': '2022-10-07 17:05Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EHAM', 'iata': 'AMS', 'name': 'Amsterdam'},
#     'scheduledTimeLocal': '2022-10-07 20:35+02:00',
#     'actualTimeLocal': '2022-10-07 20:27+02:00',
# ...
#     'scheduledTimeLocal': '2022-10-07 18:45+01:00',
#     'actualTimeLocal': '2022-10-07 18:45+01:00',
#     'scheduledTimeUtc': '2022-10-07 17:45Z',
#     'actualTimeUtc': '2022-10-07 17:45Z',
#     'terminal': '1',
#     'checkInDesk': '1204-1319',
#     'gate': '107',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:05+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:05Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'number': 'FR 8558',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'airport': {'icao': 'EBBR',
#      'iata': 'BRU',
#      'name': 'Brussels'},
#     'scheduledTimeLocal': '2022-10-07 20:50+02:00',
#     'scheduledTimeUtc': '2022-10-07 18:50Z',
#     'checkInDesk': '05',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:10Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'SN 2591',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Brussels'}},
#   {'departure': {'airport': {'icao': 'LIRP', 'iata': 'PSA', 'name': 'Pisa'},
#     'scheduledTimeLocal': '2022-10-07 20:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 18:10Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:10Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'U2 4682',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'airport': {'icao': 'LOWW', 'iata': 'VIE', 'name': 'Vienna'},
#     'scheduledTimeLocal': '2022-10-07 21:00+02:00',
#     'actualTimeLocal': '2022-10-07 21:00+02:00',
#     'scheduledTimeUtc': '2022-10-07 19:00Z',
#     'actualTimeUtc': '2022-10-07 19:00Z',
#     'terminal': '3',
#     'checkInDesk': '351-368',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:15+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:15Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'OS 239',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Austrian'}},
#   {'departure': {'airport': {'name': 'Paris'}, 'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:15+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:15Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'U2 5540',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'airport': {'icao': 'LIMC', 'iata': 'MXP', 'name': 'Milan'},
#     'scheduledTimeLocal': '2022-10-07 20:35+02:00',
#     'scheduledTimeUtc': '2022-10-07 18:35Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:20+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:20Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'number': 'FR 9',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'airport': {'icao': 'LPPT', 'iata': 'LIS', 'name': 'Lisbon'},
#     'scheduledTimeLocal': '2022-10-07 17:55+01:00',
#     'actualTimeLocal': '2022-10-07 17:55+01:00',
#     'scheduledTimeUtc': '2022-10-07 16:55Z',
#     'actualTimeUtc': '2022-10-07 16:55Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:20+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:20Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'TP 532',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 195'},
#    'airline': {'name': 'TAP Air Portugal'}},
#   {'departure': {'airport': {'icao': 'LGAV', 'iata': 'ATH', 'name': 'Athens'},
#     'scheduledTimeLocal': '2022-10-07 20:15+03:00',
#     'scheduledTimeUtc': '2022-10-07 17:15Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:20+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:20Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'U2 5938',
#    'status': 'CanceledUncertain',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf'},
#     'scheduledTimeLocal': '2022-10-07 21:15+02:00',
#     'actualTimeLocal': '2022-10-07 21:15+02:00',
#     'scheduledTimeUtc': '2022-10-07 19:15Z',
#     'actualTimeUtc': '2022-10-07 19:15Z',
#     'terminal': 'B',
#     'checkInDesk': '153,170',
#     'gate': 'A40',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:25+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:25Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'EW 8047',
#    'callSign': 'GWI27LR',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AGWN', 'modeS': '3C5EEE', 'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTimeLocal': '2022-10-07 21:15+02:00',
#     'actualTimeLocal': '2022-10-07 21:15+02:00',
#     'scheduledTimeUtc': '2022-10-07 19:15Z',
#     'actualTimeUtc': '2022-10-07 19:15Z',
#     'terminal': '1',
#     'checkInDesk': '263-461',
#     'gate': 'A52',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:25+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:25Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'LH 202',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIDD', 'modeS': '3C6484', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa'}},
#   {'departure': {'airport': {'icao': 'LSZH', 'iata': 'ZRH', 'name': 'Zurich'},
#     'scheduledTimeLocal': '2022-10-07 21:00+02:00',
#     'actualTimeLocal': '2022-10-07 21:00+02:00',
#     'scheduledTimeUtc': '2022-10-07 19:00Z',
#     'actualTimeUtc': '2022-10-07 19:00Z',
#     'checkInDesk': '1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:25+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:25Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'LX 962',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-JDE', 'modeS': '4B1816', 'model': 'Airbus A320'},
#    'airline': {'name': 'SWISS'}},
#   {'departure': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen'},
#     'scheduledTimeLocal': '2022-10-07 21:20+02:00',
#     'scheduledTimeUtc': '2022-10-07 19:20Z',
#     'terminal': '2',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:25+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:25Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'U2 5688',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'airport': {'icao': 'ESSA',
#      'iata': 'ARN',
#      'name': 'Stockholm'},
#     'scheduledTimeLocal': '2022-10-07 20:40+02:00',
#     'scheduledTimeUtc': '2022-10-07 18:40Z',
#     'terminal': '2',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:25+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:25Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'U2 5888',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'airport': {'icao': 'EGCC',
#      'iata': 'MAN',
#      'name': 'Manchester'},
#     'scheduledTimeLocal': '2022-10-07 19:35+01:00',
#     'actualTimeLocal': '2022-10-07 19:35+01:00',
#     'scheduledTimeUtc': '2022-10-07 18:35Z',
#     'actualTimeUtc': '2022-10-07 18:35Z',
#     'terminal': '3',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:30+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:30Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'number': 'FR 1145',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'airport': {'icao': 'LGTS',
#      'iata': 'SKG',
#      'name': 'Thessaloniki'},
#     'scheduledTimeLocal': '2022-10-07 20:55+03:00',
#     'scheduledTimeUtc': '2022-10-07 17:55Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:30+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:30Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'number': 'FR 1147',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'airport': {'icao': 'LIRF', 'iata': 'FCO', 'name': 'Rome'},
#     'scheduledTimeLocal': '2022-10-07 20:25+02:00',
#     'actualTimeLocal': '2022-10-07 20:25+02:00',
#     'scheduledTimeUtc': '2022-10-07 18:25Z',
#     'actualTimeUtc': '2022-10-07 18:25Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:30+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:30Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'number': 'FR 141',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'airport': {'icao': 'EGSS', 'iata': 'STN', 'name': 'London'},
#     'scheduledTimeLocal': '2022-10-07 19:45+01:00',
#     'actualTimeLocal': '2022-10-07 19:45+01:00',
#     'scheduledTimeUtc': '2022-10-07 18:45Z',
#     'actualTimeUtc': '2022-10-07 18:45Z',
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:30+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:30Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'number': 'FR 147',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'airport': {'icao': 'LIPH', 'iata': 'TSF', 'name': 'Treviso'},
#     'scheduledTimeLocal': '2022-10-07 21:00+02:00',
#     'scheduledTimeUtc': '2022-10-07 19:00Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:30+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:30Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'number': 'FR 2607',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'airport': {'icao': 'LLBG',
#      'iata': 'TLV',
#      'name': 'Tel Aviv Yafo'},
#     'scheduledTimeLocal': '2022-10-07 19:15+03:00',
#     'scheduledTimeUtc': '2022-10-07 16:15Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:30+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:30Z',
#     'terminal': '0',
#     'quality': ['Basic']},
#    'number': 'FR 6473',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair'}},
#   {'departure': {'airport': {'icao': 'LIRN', 'iata': 'NAP', 'name': 'Nápoli'},
#     'scheduledTimeLocal': '2022-10-07 20:10+02:00',
#     'scheduledTimeUtc': '2022-10-07 18:10Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:30+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:30Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'U2 4576',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'airport': {'icao': 'LEPA',
#      'iata': 'PMI',
#      'name': 'Palma De Mallorca'},
#     'scheduledTimeLocal': '2022-10-07 19:35+02:00',
#     'scheduledTimeUtc': '2022-10-07 17:35Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:30+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:30Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'U2 5816',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'airport': {'icao': 'EGLL', 'iata': 'LHR', 'name': 'London'},
#     'scheduledTimeLocal': '2022-10-07 19:40+01:00',
#     'actualTimeLocal': '2022-10-07 19:40+01:00',
#     'scheduledTimeUtc': '2022-10-07 18:40Z',
#     'actualTimeUtc': '2022-10-07 18:40Z',
#     'terminal': '5',
#     'checkInDesk': 'B',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:35+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:35Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'BA 988',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'British Airways'}},
#   {'departure': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTimeLocal': '2022-10-07 21:30+02:00',
#     'actualTimeLocal': '2022-10-07 21:30+02:00',
#     'scheduledTimeUtc': '2022-10-07 19:30Z',
#     'actualTimeUtc': '2022-10-07 19:30Z',
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:35+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:35Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'LH 1960',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa'}},
#   {'departure': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'scheduledTimeLocal': '2022-10-07 20:55+02:00',
#     'scheduledTimeUtc': '2022-10-07 18:55Z',
#     'terminal': '2F',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:40+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:40Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'AF 1134',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Air France'}},
#   {'departure': {'airport': {'icao': 'LEMD', 'iata': 'MAD', 'name': 'Madrid'},
#     'scheduledTimeLocal': '2022-10-07 19:40+02:00',
#     'actualTimeLocal': '2022-10-07 19:40+02:00',
#     'scheduledTimeUtc': '2022-10-07 17:40Z',
#     'actualTimeUtc': '2022-10-07 17:40Z',
#     'terminal': '4',
#     'checkInDesk': '850-859',
#     'gate': 'H',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:40+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:40Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'IB 3674',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321'},
#    'airline': {'name': 'Iberia'}},
#   {'departure': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam'},
#     'scheduledTimeLocal': '2022-10-07 21:30+02:00',
#     'scheduledTimeUtc': '2022-10-07 19:30Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-10-07 22:55+02:00',
#     'scheduledTimeUtc': '2022-10-07 20:55Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'U2 4568',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet'}}]}

# %%
### Option 1
arrivals_berlin = response.json()['arrivals']

def get_flight_info(flight_json):
    # terminal
    try: terminal = flight_json['arrival']['terminal']
    except: terminal = None
    # aircraft
    try: aircraft = flight_json['aircraft']['model']
    except: aircraft = None

    return {
        'dep_airport':flight_json['departure']['airport']['name'],
        'sched_arr_loc_time':flight_json['arrival']['scheduledTimeLocal'],
        'terminal':terminal,
        'status':flight_json['status'],
        'aircraft':aircraft,
        'icao_code':airport_icoa
    }

# [get_flight_info(flight) for flight in arrivals_berlin]
arrivals_berlin = pd.DataFrame([get_flight_info(flight) for flight in arrivals_berlin])
arrivals_berlin
# Out:
#     dep_airport      sched_arr_loc_time terminal             status  \
# 0          Riga  2022-10-07 14:00+02:00        0            Unknown
# 1    Luxembourg  2022-10-07 14:00+02:00        0            Unknown
# 2     Amsterdam  2022-10-07 14:00+02:00        1  CanceledUncertain
# 3        Munich  2022-10-07 14:05+02:00        1            Unknown
# 4      Istanbul  2022-10-07 14:05+02:00        1            Unknown
# ..          ...                     ...      ...                ...
# 135      London  2022-10-07 22:35+02:00        1            Unknown
# 136      Munich  2022-10-07 22:35+02:00        1            Unknown
# 137       Paris  2022-10-07 22:40+02:00        1            Unknown
# 138      Madrid  2022-10-07 22:40+02:00        1            Unknown
# 139   Amsterdam  2022-10-07 22:55+02:00        1            Unknown
#
#               aircraft icao_code
# 0       Boeing 737-800      EDDB
# 1       Boeing 737-800      EDDB
# 2          Airbus A319      EDDB
# 3    Bombardier CRJ900      EDDB
# 4          Airbus A321      EDDB
# ..                 ...       ...
# 135        Airbus A320      EDDB
# 136        Airbus A321      EDDB
# 137        Airbus A320      EDDB
# 138        Airbus A321      EDDB
# 139        Airbus A319      EDDB
#
# [140 rows x 6 columns]

# %%
### Option 2
import pandas as pd
arrivals = pd.json_normalize(response.json()['arrivals'])
# next step: select the columns you want to incude on your database
(
arrivals
    .filter(['departure.airport.name','arrival.scheduledTimeLocal',
             'arrival.terminal','status','aircraft.model'])
    .assign(icao_code = airport_icoa)
)
# Out:
#     departure.airport.name arrival.scheduledTimeLocal arrival.terminal  \
# 0                     Riga     2022-10-07 14:00+02:00                0
# 1               Luxembourg     2022-10-07 14:00+02:00                0
# 2                Amsterdam     2022-10-07 14:00+02:00                1
# 3                   Munich     2022-10-07 14:05+02:00                1
# 4                 Istanbul     2022-10-07 14:05+02:00                1
# ..                     ...                        ...              ...
# 135                 London     2022-10-07 22:35+02:00                1
# 136                 Munich     2022-10-07 22:35+02:00                1
# 137                  Paris     2022-10-07 22:40+02:00                1
# 138                 Madrid     2022-10-07 22:40+02:00                1
# 139              Amsterdam     2022-10-07 22:55+02:00                1
#
#                 status     aircraft.model icao_code
# 0              Unknown     Boeing 737-800      EDDB
# 1              Unknown     Boeing 737-800      EDDB
# 2    CanceledUncertain        Airbus A319      EDDB
# 3              Unknown  Bombardier CRJ900      EDDB
# 4              Unknown        Airbus A321      EDDB
# ..                 ...                ...       ...
# 135            Unknown        Airbus A320      EDDB
# 136            Unknown        Airbus A321      EDDB
# 137            Unknown        Airbus A320      EDDB
# 138            Unknown        Airbus A321      EDDB
# 139            Unknown        Airbus A319      EDDB
#
# [140 rows x 6 columns]

# %% [markdown]
# ## Wheather API

# %%
city = "Berlin"
country = "DE"

# %% [markdown]
# ### Connecting to OWM API

# %%
# achieve the same result with the wather api
response = requests.get(f'http://api.openweathermap.org/data/2.5/forecast/?q={city},{country}&appid={OWM_key}&units=metric&lang=en')

from IPython.display import JSON
JSON(response.json())

# %%
forecast_api = response.json()['list']
# look for the fields that could ve relevant: 
# better field descriptions https://www.weatherbit.io/api/weather-forecast-5-day

weather_info = []

# datetime, temperature, wind, prob_perc, rain_qty, snow = [], [], [], [], [], []
for forecast_3h in forecast_api: 
    weather_hour = {}
    # datetime utc
    weather_hour['datetime'] = forecast_3h['dt_txt']
    # temperature 
    weather_hour['temperature'] = forecast_3h['main']['temp']
    # wind
    weather_hour['wind'] = forecast_3h['wind']['speed']
    # probability precipitation 
    try: weather_hour['prob_perc'] = float(forecast_3h['pop'])
    except: weather_hour['prob_perc'] = 0
    # rain
    try: weather_hour['rain_qty'] = float(forecast_3h['rain']['3h'])
    except: weather_hour['rain_qty'] = 0
    # wind 
    try: weather_hour['snow'] = float(forecast_3h['snow']['3h'])
    except: weather_hour['snow'] = 0
    weather_hour['municipality_iso_country'] = city + ',' + country
    weather_info.append(weather_hour)
    
weather_data = pd.DataFrame(weather_info)
weather_data.head()
# Out:
#               datetime  temperature  wind  prob_perc  rain_qty  snow  \
# 0  2022-10-07 15:00:00        18.04  3.65        0.0         0     0
# 1  2022-10-07 18:00:00        15.33  2.62        0.0         0     0
# 2  2022-10-07 21:00:00        12.76  2.58        0.0         0     0
# 3  2022-10-08 00:00:00        12.02  2.41        0.0         0     0
# 4  2022-10-08 03:00:00        11.08  2.45        0.0         0     0
#
#   municipality_iso_country
# 0                Berlin,DE
# 1                Berlin,DE
# 2                Berlin,DE
# 3                Berlin,DE
# 4                Berlin,DE

# %% [markdown]
# ## Population data

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import unicodedata

# cities = ['Berlin', 'Hamburg', 'Frankfurt','Munich','Stuttgart','Leipzig','Cologne','Dresden','Hannover','Paris', 'Barcelona','Lisbon','Madrid']
cities = ['Berlin','Paris','Amsterdam','Barcelona','Rome','Lisbon','Prague','Vienna','Madrid']

def City_info(soup):
    
    ret_dict = {}
    ret_dict['city'] = soup.h1.get_text()
    
    
    if soup.select_one('.mergedrow:-soup-contains("Mayor")>.infobox-label') != None:
        i = soup.select_one('.mergedrow:-soup-contains("Mayor")>.infobox-label')
        mayor_name_html = i.find_next_sibling()
        mayor_name = unicodedata.normalize('NFKD',mayor_name_html.get_text())
        ret_dict['mayor']  = mayor_name
    
    if soup.select_one('.mergedrow:-soup-contains("City")>.infobox-label') != None:
        j =  soup.select_one('.mergedrow:-soup-contains("City")>.infobox-label')
        area = j.find_next_sibling('td').get_text()
        ret_dict['city_size'] = unicodedata.normalize('NFKD',area)

    if soup.select_one('.mergedtoprow:-soup-contains("Elevation")>.infobox-data') != None:
        k = soup.select_one('.mergedtoprow:-soup-contains("Elevation")>.infobox-data')
        elevation_html = k.get_text()
        ret_dict['elevation'] = unicodedata.normalize('NFKD',elevation_html)
    
    if soup.select_one('.mergedtoprow:-soup-contains("Population")') != None:
        l = soup.select_one('.mergedtoprow:-soup-contains("Population")')
        c_pop = l.findNext('td').get_text()
        ret_dict['city_population'] = c_pop
    
    if soup.select_one('.infobox-label>[title^=Urban]') != None:
        m = soup.select_one('.infobox-label>[title^=Urban]')
        u_pop = m.findNext('td')
        ret_dict['urban_population'] = u_pop.get_text()

    if soup.select_one('.infobox-label>[title^=Metro]') != None:
        n = soup.select_one('.infobox-label>[title^=Metro]')
        m_pop = n.findNext('td')
        ret_dict['metro_population'] = m_pop.get_text()
    
    if soup.select_one('.latitude') != None:
        o = soup.select_one('.latitude')
        ret_dict['lat'] = o.get_text()

    if soup.select_one('.longitude') != None:    
        p = soup.select_one('.longitude')
        ret_dict['long'] = p.get_text()
    
    return ret_dict

list_of_city_info = []
for city in cities:
    url = 'https://en.wikipedia.org/wiki/{}'.format(city)
    web = requests.get(url,'html.parser')
    soup = bs(web.content)
    list_of_city_info.append(City_info(soup))
df_cities = pd.DataFrame(list_of_city_info)
# df_cities = df_cities.set_index('city')
df_cities
# Out:
#         city                                      mayor  \
# 0     Berlin                     Franziska Giffey (SPD)
# 1      Paris                          Anne Hidalgo (PS)
# 2  Amsterdam                         Femke Halsema (GL)
# 3  Barcelona  Ada Colau Ballano[1] (Barcelona en Comú)
# 4       Rome                       Strong Mayor–Council
# 5     Lisbon                              Carlos Moedas
# 6     Prague                    Zdeněk Hřib (Pirates)
# 7     Vienna                      Michael Ludwig (SPÖ)
# 8     Madrid          José Luis Martínez-Almeida (PP)
#
#                  city_size                                          elevation  \
# 0  891.7 km2 (344.3 sq mi)                                      34 m (112 ft)
# 1                      NaN         28–131 m (92–430 ft) (avg. 78 m or 256 ft)
# 2                      NaN                                       −2 m (−7 ft)
# 3   101.4 km2 (39.2 sq mi)                                       12 m (39 ft)
# 4             4,342,212[2]                                       21 m (69 ft)
# 5                      NaN                                         2 m (7 ft)
# 6                      NaN                                                NaN
# 7                      NaN  151 (Lobau) – 542 (Hermannskogel) m (495–1,778...
# 8                      NaN                                   650 m (2,130 ft)
#
#                 city_population urban_population metro_population         lat  \
# 0                     3,769,495        4,473,101        6,144,600  52°31′12″N
# 1                     2,165,423       10,858,852       13,024,518  48°51′24″N
# 2                       907,976        1,558,755              NaN     52°22′N
# 3                     1,620,343     4,840,000[3]     5,474,482[4]     41°23′N
# 4  1st in Italy (3rd in the EU)              NaN     Rome Capital  41°53′36″N
# 5                    544,851[1]     2,719,000[4]  2,871,133[2][3]  38°43′31″N
# 6                     1,275,406              NaN     2,709,418[4]  50°05′15″N
# 7    1st in Austria (6th in EU)        1,951,354        2,890,577     48°12′N
# 8                     3,223,334     6,211,000[2]     6,791,667[1]  40°25′00″N
#
#          long
# 0  13°24′18″E
# 1   2°21′08″E
# 2      4°54′E
# 3      2°11′E
# 4  12°28′58″E
# 5   9°09′00″W
# 6  14°25′17″E
# 7     16°22′E
# 8  03°42′09″W

# %% [markdown]
# ## Airports data

# %%
import pandas as pd

airports_cities = (
pd.read_csv('airports.csv')
    .query('type == "large_airport"')
    .filter(['name','latitude_deg','longitude_deg','iso_country','iso_region','municipality','gps_code','iata_code'])
    .rename(columns={'gps_code':'icao_code'})
    .assign(municipality_iso_country = lambda x: x['municipality'] + ',' + x['iso_country'])
)
airports_cities.head()
# Out:
#                                               name  latitude_deg  \
# 10890                Honiara International Airport     -9.428000
# 12461  Port Moresby Jacksons International Airport     -9.443380
# 12981               Keflavik International Airport     63.985001
# 13028  Priština Adem Jashari International Airport     42.572800
# 17254                               Guodu Air Base     36.001741
#
#        longitude_deg iso_country iso_region    municipality icao_code  \
# 10890     160.054993          SB      SB-CT         Honiara      AGGH
# 12461     147.220001          PG     PG-NCD    Port Moresby      AYPY
# 12981     -22.605600          IS       IS-2       Reykjavík      BIKF
# 13028      21.035801          XK      XK-01       Prishtina      BKPR
# 17254     117.632010          CN      CN-37  Xintai, Tai'an       NaN
#
#       iata_code municipality_iso_country
# 10890       HIR               Honiara,SB
# 12461       POM          Port Moresby,PG
# 12981       KEF             Reykjavík,IS
# 13028       PRN             Prishtina,XK
# 17254       NaN        Xintai, Tai'an,CN

# %%
airports_cities.query('municipality == "Berlin"')
# Out:
#                              name  latitude_deg  longitude_deg iso_country  \
# 20244  Berlin Brandenburg Airport     52.351389      13.493889          DE
#
#       iso_region municipality icao_code iata_code municipality_iso_country
# 20244      DE-BR       Berlin      EDDB       BER                Berlin,DE

# %% [markdown]
# ## Check the tables

# %%
arrivals_berlin.head()
# Out:
#   dep_airport      sched_arr_loc_time terminal             status  \
# 0        Riga  2022-10-07 14:00+02:00        0            Unknown
# 1  Luxembourg  2022-10-07 14:00+02:00        0            Unknown
# 2   Amsterdam  2022-10-07 14:00+02:00        1  CanceledUncertain
# 3      Munich  2022-10-07 14:05+02:00        1            Unknown
# 4    Istanbul  2022-10-07 14:05+02:00        1            Unknown
#
#             aircraft icao_code
# 0     Boeing 737-800      EDDB
# 1     Boeing 737-800      EDDB
# 2        Airbus A319      EDDB
# 3  Bombardier CRJ900      EDDB
# 4        Airbus A321      EDDB

# %%
arrivals_berlin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   dep_airport         140 non-null    object
#  1   sched_arr_loc_time  140 non-null    object
#  2   terminal            140 non-null    object
#  3   status              140 non-null    object
#  4   aircraft            140 non-null    object
#  5   icao_code           140 non-null    object
# dtypes: object(6)
# memory usage: 6.7+ KB

# %%
weather_data.head()
# Out:
#               datetime  temperature  wind  prob_perc  rain_qty  snow  \
# 0  2022-03-31 12:00:00         7.54  6.81        0.0       0.0     0
# 1  2022-03-31 15:00:00         7.54  6.72        0.0       0.0     0
# 2  2022-03-31 18:00:00         6.15  6.62        0.0       0.0     0
# 3  2022-03-31 21:00:00         3.81  6.85        0.0       0.0     0
# 4  2022-04-01 00:00:00         1.48  6.39        0.0       0.0     0
#
#   municipality_iso_country
# 0                Berlin,DE
# 1                Berlin,DE
# 2                Berlin,DE
# 3                Berlin,DE
# 4                Berlin,DE

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   datetime                  40 non-null     object
#  1   temperature               40 non-null     float64
#  2   wind                      40 non-null     float64
#  3   prob_perc                 40 non-null     float64
#  4   rain_qty                  40 non-null     int64
#  5   snow                      40 non-null     int64
#  6   municipality_iso_country  40 non-null     object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 2.3+ KB

# %%
airports_cities.head()
# Out:
#                                               name  latitude_deg  \
# 10890                Honiara International Airport     -9.428000
# 12461  Port Moresby Jacksons International Airport     -9.443380
# 12981               Keflavik International Airport     63.985001
# 13028  Priština Adem Jashari International Airport     42.572800
# 17254                               Guodu Air Base     36.001741
#
#        longitude_deg iso_country iso_region    municipality icao_code  \
# 10890     160.054993          SB      SB-CT         Honiara      AGGH
# 12461     147.220001          PG     PG-NCD    Port Moresby      AYPY
# 12981     -22.605600          IS       IS-2       Reykjavík      BIKF
# 13028      21.035801          XK      XK-01       Prishtina      BKPR
# 17254     117.632010          CN      CN-37  Xintai, Tai'an       NaN
#
#       iata_code municipality_iso_country
# 10890       HIR               Honiara,SB
# 12461       POM          Port Moresby,PG
# 12981       KEF             Reykjavík,IS
# 13028       PRN             Prishtina,XK
# 17254       NaN        Xintai, Tai'an,CN

# %%
airports_cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 624 entries, 10890 to 68323
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   name                      624 non-null    object
#  1   latitude_deg              624 non-null    float64
#  2   longitude_deg             624 non-null    float64
#  3   iso_country               623 non-null    object
#  4   iso_region                624 non-null    object
#  5   municipality              619 non-null    object
#  6   icao_code                 619 non-null    object
#  7   iata_code                 617 non-null    object
#  8   municipality_iso_country  618 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 48.8+ KB

# %%
cities = airports_cities.filter(['municipality','iso_country','municipality_iso_country']).drop_duplicates()
cities.head()
# Out:
#          municipality iso_country municipality_iso_country
# 10890         Honiara          SB               Honiara,SB
# 12461    Port Moresby          PG          Port Moresby,PG
# 12981       Reykjavík          IS             Reykjavík,IS
# 13028       Prishtina          XK             Prishtina,XK
# 17254  Xintai, Tai'an          CN        Xintai, Tai'an,CN

# %%
airports_cities.merge(arrivals_berlin, on='icao_code', how='inner').merge(weather_data, on='municipality_iso_country', how='inner').head()
# Out:
#                          name  latitude_deg  longitude_deg iso_country  \
# 0  Berlin Brandenburg Airport     52.351389      13.493889          DE
# 1  Berlin Brandenburg Airport     52.351389      13.493889          DE
# 2  Berlin Brandenburg Airport     52.351389      13.493889          DE
# 3  Berlin Brandenburg Airport     52.351389      13.493889          DE
# 4  Berlin Brandenburg Airport     52.351389      13.493889          DE
#
#   iso_region municipality icao_code iata_code municipality_iso_country  \
# 0      DE-BR       Berlin      EDDB       BER                Berlin,DE
# 1      DE-BR       Berlin      EDDB       BER                Berlin,DE
# 2      DE-BR       Berlin      EDDB       BER                Berlin,DE
# 3      DE-BR       Berlin      EDDB       BER                Berlin,DE
# 4      DE-BR       Berlin      EDDB       BER                Berlin,DE
#
#   dep_airport      sched_arr_loc_time terminal   status        aircraft  \
# 0        Riga  2022-10-07 14:00+02:00        0  Unknown  Boeing 737-800
# 1        Riga  2022-10-07 14:00+02:00        0  Unknown  Boeing 737-800
# 2        Riga  2022-10-07 14:00+02:00        0  Unknown  Boeing 737-800
# 3        Riga  2022-10-07 14:00+02:00        0  Unknown  Boeing 737-800
# 4        Riga  2022-10-07 14:00+02:00        0  Unknown  Boeing 737-800
#
#               datetime  temperature  wind  prob_perc  rain_qty  snow
# 0  2022-10-07 15:00:00        18.04  3.65        0.0         0     0
# 1  2022-10-07 18:00:00        15.33  2.62        0.0         0     0
# 2  2022-10-07 21:00:00        12.76  2.58        0.0         0     0
# 3  2022-10-08 00:00:00        12.02  2.41        0.0         0     0
# 4  2022-10-08 03:00:00        11.08  2.45        0.0         0     0

# %%
df_cities
# Out:
#         city                                      mayor  \
# 0     Berlin                     Franziska Giffey (SPD)
# 1      Paris                          Anne Hidalgo (PS)
# 2  Amsterdam                         Femke Halsema (GL)
# 3  Barcelona  Ada Colau Ballano[1] (Barcelona en Comú)
# 4       Rome                       Strong Mayor–Council
# 5     Lisbon                              Carlos Moedas
# 6     Prague                    Zdeněk Hřib (Pirates)
# 7     Vienna                      Michael Ludwig (SPÖ)
# 8     Madrid          José Luis Martínez-Almeida (PP)
#
#                  city_size                                          elevation  \
# 0  891.7 km2 (344.3 sq mi)                                      34 m (112 ft)
# 1                      NaN         28–131 m (92–430 ft) (avg. 78 m or 256 ft)
# 2                      NaN                                       −2 m (−7 ft)
# 3   101.4 km2 (39.2 sq mi)                                       12 m (39 ft)
# 4             4,342,212[2]                                       21 m (69 ft)
# 5                      NaN                                         2 m (7 ft)
# 6                      NaN                                                NaN
# 7                      NaN  151 (Lobau) – 542 (Hermannskogel) m (495–1,778...
# 8                      NaN                                   650 m (2,130 ft)
#
#                 city_population urban_population metro_population         lat  \
# 0                     3,769,495        4,473,101        6,144,600  52°31′12″N
# 1                     2,165,423       10,858,852       13,024,518  48°51′24″N
# 2                       907,976        1,558,755              NaN     52°22′N
# 3                     1,620,343     4,840,000[3]     5,474,482[4]     41°23′N
# 4  1st in Italy (3rd in the EU)              NaN     Rome Capital  41°53′36″N
# 5                    544,851[1]     2,719,000[4]  2,871,133[2][3]  38°43′31″N
# 6                     1,275,406              NaN     2,709,418[4]  50°05′15″N
# 7    1st in Austria (6th in EU)        1,951,354        2,890,577     48°12′N
# 8                     3,223,334     6,211,000[2]     6,791,667[1]  40°25′00″N
#
#          long
# 0  13°24′18″E
# 1   2°21′08″E
# 2      4°54′E
# 3      2°11′E
# 4  12°28′58″E
# 5   9°09′00″W
# 6  14°25′17″E
# 7     16°22′E
# 8  03°42′09″W

# %%
df_cities['municipality_iso_country'] = [
    'Berlin,DE',
    'Paris,FR',
    'Amsterdam,NL',
    'Barcelona,ES',
    'Rome,IT',
    'Lisbon,PT',
    'Prague,CZE',
    'Vienna,AT',
    'Madrid,ES'
]

# %% [markdown]
# ## Update data into database

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   datetime                  40 non-null     object
#  1   temperature               40 non-null     float64
#  2   wind                      40 non-null     float64
#  3   prob_perc                 40 non-null     float64
#  4   rain_qty                  40 non-null     int64
#  5   snow                      40 non-null     int64
#  6   municipality_iso_country  40 non-null     object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 2.3+ KB

# %% [markdown]
# ### `sqlalchemy`

# %% [markdown]
# #### Establish the connection

# %%
import sqlalchemy
import pymysql

# %%
schema="data_engineering"
host="127.0.0.1"
user="root"
password="root"
port=3306
con = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

# %% [markdown]
# #### Update the tables

# %%
(
df_cities
    .dropna()
    .rename(
        columns={
            'lat':'latitude',
            'long':'longitude'
            }
        )
    .to_sql('cities', con=con, if_exists='append', index=False)
    )
# Out:
# 2

# %%
airports_cities.dropna().to_sql('airports_cities', if_exists='append', con=con, index=False)
# Out:
# 611

# %%
weather_data.assign(datetime = lambda x: pd.to_datetime(x['datetime'])).to_sql('weather', if_exists='append', con=con, index=False)
# Out:
# 40

# %%
arrivals_berlin
# Out:
#     dep_airport      sched_arr_loc_time terminal             status  \
# 0          Riga  2022-10-07 14:00+02:00        0            Unknown
# 1    Luxembourg  2022-10-07 14:00+02:00        0            Unknown
# 2     Amsterdam  2022-10-07 14:00+02:00        1  CanceledUncertain
# 3        Munich  2022-10-07 14:05+02:00        1            Unknown
# 4      Istanbul  2022-10-07 14:05+02:00        1            Unknown
# ..          ...                     ...      ...                ...
# 135      London  2022-10-07 22:35+02:00        1            Unknown
# 136      Munich  2022-10-07 22:35+02:00        1            Unknown
# 137       Paris  2022-10-07 22:40+02:00        1            Unknown
# 138      Madrid  2022-10-07 22:40+02:00        1            Unknown
# 139   Amsterdam  2022-10-07 22:55+02:00        1            Unknown
#
#               aircraft icao_code
# 0       Boeing 737-800      EDDB
# 1       Boeing 737-800      EDDB
# 2          Airbus A319      EDDB
# 3    Bombardier CRJ900      EDDB
# 4          Airbus A321      EDDB
# ..                 ...       ...
# 135        Airbus A320      EDDB
# 136        Airbus A321      EDDB
# 137        Airbus A320      EDDB
# 138        Airbus A321      EDDB
# 139        Airbus A319      EDDB
#
# [140 rows x 6 columns]

# %%
import numpy as np
(
arrivals_berlin
    .replace({np.nan},'unknown')
    .assign(sched_arr_loc_time = lambda x: pd.to_datetime(x['sched_arr_loc_time']))
    .to_sql('arrivals', if_exists='append', con=con, index=False))
# Out:
# 140
